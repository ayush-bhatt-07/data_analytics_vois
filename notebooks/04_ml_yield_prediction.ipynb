# %% [markdown]
# # ML: yield prediction
# **KrishiDrishti** | Phases 7-9
#
# Target definition, leakage prevention, simple baselines first, cross-validation, MAE / RMSE / R2.
#
# > Status: skeleton only. No analysis has been run yet.

# %%
# Setup: make the project root importable, then load the shared helpers
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.config import *
from src.data_loader import load_raw
from src.io_utils import save_figure, save_table

pd.set_option("display.max_columns", 50)
df_raw = load_raw()          # untouched raw data
print(df_raw.shape)
